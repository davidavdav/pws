# %%
from Tkinter import *
from random import randint
import tkMessageBox


"""

Dit programma is gemaakt door Dennis Hilhorst
copyright 2016


"""


CubeFront=[
    "blue", "blue", "blue",
    "blue", "blue", "blue",
    "blue", "blue", "blue"
]

CubeBack=[
    "green", "green", "green",
    "green", "green", "green",
    "green", "green", "green"
]

CubeUp=[
    "white", "white", "white",
    "white", "white", "white",
    "white", "white", "white"
]

CubeDown=[
    "yellow", "yellow", "yellow",
    "yellow", "yellow", "yellow",
    "yellow", "yellow", "yellow"
]

CubeLeft=[
    "red", "red", "red",
    "red", "red", "red",
    "red", "red", "red"
]

CubeRight=[
    "orange", "orange", "orange",
    "orange", "orange", "orange",
    "orange", "orange", "orange"
]


MovesList=["F", "B", "R", "L", "U", "D", "F'", "B'", "R'", "L'", "U'", "D'"]

CubeFrontTemp  =  list(CubeFront)
CubeBackTemp   =  list(CubeBack)
CubeUpTemp     =  list(CubeUp)
CubeDownTemp   =  list(CubeDown)
CubeLeftTemp   =  list(CubeLeft)
CubeRightTemp  =  list(CubeRight)

ShuffleList=[]

"""def reEqual():
    CubeFrontTemp  =  list(CubeFront)
    CubeBackTemp   =  list(CubeBack)
    CubeUpTemp     =  list(CubeUp)
    CubeDownTemp   =  list(CubeDown)
    CubeLeftTemp   =  list(CubeLeft)
    CubeRightTemp  =  list(CubeRight)
    
    Deze werkt niet..."""
    
def reFresh():
    CubeVisual.itemconfig(U0, fill=CubeUp[0])
    CubeVisual.itemconfig(U1, fill=CubeUp[1])
    CubeVisual.itemconfig(U2, fill=CubeUp[2])
    CubeVisual.itemconfig(U3, fill=CubeUp[3])
    CubeVisual.itemconfig(U4, fill=CubeUp[4])
    CubeVisual.itemconfig(U5, fill=CubeUp[5])
    CubeVisual.itemconfig(U6, fill=CubeUp[6])
    CubeVisual.itemconfig(U7, fill=CubeUp[7])
    CubeVisual.itemconfig(U8, fill=CubeUp[8])
    
    CubeVisual.itemconfig(B0, fill=CubeBack[0])
    CubeVisual.itemconfig(B1, fill=CubeBack[1])
    CubeVisual.itemconfig(B2, fill=CubeBack[2])
    CubeVisual.itemconfig(B3, fill=CubeBack[3])
    CubeVisual.itemconfig(B4, fill=CubeBack[4])
    CubeVisual.itemconfig(B5, fill=CubeBack[5])
    CubeVisual.itemconfig(B6, fill=CubeBack[6])
    CubeVisual.itemconfig(B7, fill=CubeBack[7])
    CubeVisual.itemconfig(B8, fill=CubeBack[8])
    
    CubeVisual.itemconfig(L0, fill=CubeLeft[0])
    CubeVisual.itemconfig(L1, fill=CubeLeft[1])
    CubeVisual.itemconfig(L2, fill=CubeLeft[2])
    CubeVisual.itemconfig(L3, fill=CubeLeft[3])
    CubeVisual.itemconfig(L4, fill=CubeLeft[4])
    CubeVisual.itemconfig(L5, fill=CubeLeft[5])
    CubeVisual.itemconfig(L6, fill=CubeLeft[6])
    CubeVisual.itemconfig(L7, fill=CubeLeft[7])
    CubeVisual.itemconfig(L8, fill=CubeLeft[8])
    
    CubeVisual.itemconfig(F0, fill=CubeFront[0])
    CubeVisual.itemconfig(F1, fill=CubeFront[1])
    CubeVisual.itemconfig(F2, fill=CubeFront[2])
    CubeVisual.itemconfig(F3, fill=CubeFront[3])
    CubeVisual.itemconfig(F4, fill=CubeFront[4])
    CubeVisual.itemconfig(F5, fill=CubeFront[5])
    CubeVisual.itemconfig(F6, fill=CubeFront[6])
    CubeVisual.itemconfig(F7, fill=CubeFront[7])
    CubeVisual.itemconfig(F8, fill=CubeFront[8])
    
    CubeVisual.itemconfig(R0, fill=CubeRight[0])
    CubeVisual.itemconfig(R1, fill=CubeRight[1])
    CubeVisual.itemconfig(R2, fill=CubeRight[2])
    CubeVisual.itemconfig(R3, fill=CubeRight[3])
    CubeVisual.itemconfig(R4, fill=CubeRight[4])
    CubeVisual.itemconfig(R5, fill=CubeRight[5])
    CubeVisual.itemconfig(R6, fill=CubeRight[6])
    CubeVisual.itemconfig(R7, fill=CubeRight[7])
    CubeVisual.itemconfig(R8, fill=CubeRight[8])
    
    CubeVisual.itemconfig(D0, fill=CubeDown[0])
    CubeVisual.itemconfig(D1, fill=CubeDown[1])
    CubeVisual.itemconfig(D2, fill=CubeDown[2])
    CubeVisual.itemconfig(D3, fill=CubeDown[3])
    CubeVisual.itemconfig(D4, fill=CubeDown[4])
    CubeVisual.itemconfig(D5, fill=CubeDown[5])
    CubeVisual.itemconfig(D6, fill=CubeDown[6])
    CubeVisual.itemconfig(D7, fill=CubeDown[7])
    CubeVisual.itemconfig(D8, fill=CubeDown[8])
    

def moveF():
    CubeFrontTemp  =  list(CubeFront)
    CubeBackTemp   =  list(CubeBack)
    CubeUpTemp     =  list(CubeUp)
    CubeDownTemp   =  list(CubeDown)
    CubeLeftTemp   =  list(CubeLeft)
    CubeRightTemp  =  list(CubeRight)
    
    CubeFront[0]=CubeFrontTemp[6]
    CubeFront[1]=CubeFrontTemp[3]
    CubeFront[2]=CubeFrontTemp[0]
    CubeFront[3]=CubeFrontTemp[7]
    CubeFront[4]=CubeFrontTemp[4]
    CubeFront[5]=CubeFrontTemp[1]
    CubeFront[6]=CubeFrontTemp[8]
    CubeFront[7]=CubeFrontTemp[5]
    CubeFront[8]=CubeFrontTemp[2]

    CubeUp[6]=CubeLeftTemp[8]
    CubeUp[7]=CubeLeftTemp[5]
    CubeUp[8]=CubeLeftTemp[2]

    CubeLeft[2]=CubeDownTemp[0]
    CubeLeft[5]=CubeDownTemp[1]
    CubeLeft[8]=CubeDownTemp[2]

    CubeDown[0]=CubeRightTemp[6]
    CubeDown[1]=CubeRightTemp[3]
    CubeDown[2]=CubeRightTemp[0]

    CubeRight[0]=CubeUpTemp[6]
    CubeRight[3]=CubeUpTemp[7]
    CubeRight[6]=CubeUpTemp[8]
    
    reFresh()
    
def moveFcounter():
    CubeFrontTemp  =  list(CubeFront)
    CubeBackTemp   =  list(CubeBack)
    CubeUpTemp     =  list(CubeUp)
    CubeDownTemp   =  list(CubeDown)
    CubeLeftTemp   =  list(CubeLeft)
    CubeRightTemp  =  list(CubeRight)
    
    CubeFront[0]=CubeFrontTemp[2]
    CubeFront[1]=CubeFrontTemp[5]
    CubeFront[2]=CubeFrontTemp[8]
    CubeFront[3]=CubeFrontTemp[1]
    CubeFront[4]=CubeFrontTemp[4]
    CubeFront[5]=CubeFrontTemp[7]
    CubeFront[6]=CubeFrontTemp[0]
    CubeFront[7]=CubeFrontTemp[3]
    CubeFront[8]=CubeFrontTemp[6]

    CubeUp[6]=CubeRightTemp[0]
    CubeUp[7]=CubeRightTemp[3]
    CubeUp[8]=CubeRightTemp[6]

    CubeLeft[2]=CubeUpTemp[8]
    CubeLeft[5]=CubeUpTemp[7]
    CubeLeft[8]=CubeUpTemp[6]

    CubeDown[0]=CubeLeftTemp[2]
    CubeDown[1]=CubeLeftTemp[5]
    CubeDown[2]=CubeLeftTemp[8]

    CubeRight[0]=CubeDownTemp[2]
    CubeRight[3]=CubeDownTemp[1]
    CubeRight[6]=CubeDownTemp[0]
    
    reFresh()

def moveB():
    CubeFrontTemp  =  list(CubeFront)
    CubeBackTemp   =  list(CubeBack)
    CubeUpTemp     =  list(CubeUp)
    CubeDownTemp   =  list(CubeDown)
    CubeLeftTemp   =  list(CubeLeft)
    CubeRightTemp  =  list(CubeRight)
    
    CubeBack[0]=CubeBackTemp[6]
    CubeBack[1]=CubeBackTemp[3]
    CubeBack[2]=CubeBackTemp[0]
    CubeBack[3]=CubeBackTemp[7]
    CubeBack[4]=CubeBackTemp[4]
    CubeBack[5]=CubeBackTemp[1]
    CubeBack[6]=CubeBackTemp[8]
    CubeBack[7]=CubeBackTemp[5]
    CubeBack[8]=CubeBackTemp[2]

    CubeUp[0]=CubeRightTemp[2]
    CubeUp[1]=CubeRightTemp[5]
    CubeUp[2]=CubeRightTemp[8]

    CubeLeft[0]=CubeUpTemp[2]
    CubeLeft[3]=CubeUpTemp[1]
    CubeLeft[6]=CubeUpTemp[0]

    CubeDown[6]=CubeLeftTemp[0]
    CubeDown[7]=CubeLeftTemp[3]
    CubeDown[8]=CubeLeftTemp[6]

    CubeRight[2]=CubeDownTemp[8]
    CubeRight[5]=CubeDownTemp[7]
    CubeRight[8]=CubeDownTemp[6]
    
    reFresh()
    
def moveBcounter():
    CubeFrontTemp  =  list(CubeFront)
    CubeBackTemp   =  list(CubeBack)
    CubeUpTemp     =  list(CubeUp)
    CubeDownTemp   =  list(CubeDown)
    CubeLeftTemp   =  list(CubeLeft)
    CubeRightTemp  =  list(CubeRight)
    
    CubeBack[0]=CubeBackTemp[2]
    CubeBack[1]=CubeBackTemp[5]
    CubeBack[2]=CubeBackTemp[8]
    CubeBack[3]=CubeBackTemp[1]
    CubeBack[4]=CubeBackTemp[4]
    CubeBack[5]=CubeBackTemp[7]
    CubeBack[6]=CubeBackTemp[0]
    CubeBack[7]=CubeBackTemp[3]
    CubeBack[8]=CubeBackTemp[6]

    CubeUp[0]=CubeLeftTemp[6]
    CubeUp[1]=CubeLeftTemp[3]
    CubeUp[2]=CubeLeftTemp[0]

    CubeLeft[0]=CubeDownTemp[6]
    CubeLeft[3]=CubeDownTemp[7]
    CubeLeft[6]=CubeDownTemp[8]

    CubeDown[6]=CubeRightTemp[8]
    CubeDown[7]=CubeRightTemp[5]
    CubeDown[8]=CubeRightTemp[2]

    CubeRight[2]=CubeUpTemp[0]
    CubeRight[5]=CubeUpTemp[1]
    CubeRight[8]=CubeUpTemp[2]
    
    reFresh()
    
    
def moveU():
    CubeFrontTemp  =  list(CubeFront)
    CubeBackTemp   =  list(CubeBack)
    CubeUpTemp     =  list(CubeUp)
    CubeDownTemp   =  list(CubeDown)
    CubeLeftTemp   =  list(CubeLeft)
    CubeRightTemp  =  list(CubeRight)
    
    CubeUp[0]=CubeUpTemp[6]
    CubeUp[1]=CubeUpTemp[3]
    CubeUp[2]=CubeUpTemp[0]
    CubeUp[3]=CubeUpTemp[7]
    CubeUp[4]=CubeUpTemp[4]
    CubeUp[5]=CubeUpTemp[1]
    CubeUp[6]=CubeUpTemp[8]
    CubeUp[7]=CubeUpTemp[5]
    CubeUp[8]=CubeUpTemp[2]

    CubeFront[0]=CubeRightTemp[0]
    CubeFront[1]=CubeRightTemp[1]
    CubeFront[2]=CubeRightTemp[2]

    CubeRight[0]=CubeBackTemp[0]
    CubeRight[1]=CubeBackTemp[1]
    CubeRight[2]=CubeBackTemp[2]

    CubeLeft[0]=CubeFrontTemp[0]
    CubeLeft[1]=CubeFrontTemp[1]
    CubeLeft[2]=CubeFrontTemp[2]

    CubeBack[0]=CubeLeftTemp[0]
    CubeBack[1]=CubeLeftTemp[1]
    CubeBack[2]=CubeLeftTemp[2]
    
    reFresh()

def moveUcounter():
    CubeFrontTemp  =  list(CubeFront)
    CubeBackTemp   =  list(CubeBack)
    CubeUpTemp     =  list(CubeUp)
    CubeDownTemp   =  list(CubeDown)
    CubeLeftTemp   =  list(CubeLeft)
    CubeRightTemp  =  list(CubeRight)
    
    CubeUp[0]=CubeUpTemp[2]
    CubeUp[1]=CubeUpTemp[5]
    CubeUp[2]=CubeUpTemp[8]
    CubeUp[3]=CubeUpTemp[1]
    CubeUp[4]=CubeUpTemp[4]
    CubeUp[5]=CubeUpTemp[7]
    CubeUp[6]=CubeUpTemp[0]
    CubeUp[7]=CubeUpTemp[3]
    CubeUp[8]=CubeUpTemp[6]

    CubeFront[0]=CubeLeftTemp[0]
    CubeFront[1]=CubeLeftTemp[1]
    CubeFront[2]=CubeLeftTemp[2]

    CubeRight[0]=CubeFrontTemp[0]
    CubeRight[1]=CubeFrontTemp[1]
    CubeRight[2]=CubeFrontTemp[2]

    CubeLeft[0]=CubeBackTemp[0]
    CubeLeft[1]=CubeBackTemp[1]
    CubeLeft[2]=CubeBackTemp[2]

    CubeBack[0]=CubeRightTemp[0]
    CubeBack[1]=CubeRightTemp[1]
    CubeBack[2]=CubeRightTemp[2]
    
    reFresh()
    
def moveD():
    CubeFrontTemp  =  list(CubeFront)
    CubeBackTemp   =  list(CubeBack)
    CubeUpTemp     =  list(CubeUp)
    CubeDownTemp   =  list(CubeDown)
    CubeLeftTemp   =  list(CubeLeft)
    CubeRightTemp  =  list(CubeRight)
    
    CubeDown[0]=CubeDownTemp[6]
    CubeDown[1]=CubeDownTemp[3]
    CubeDown[2]=CubeDownTemp[0]
    CubeDown[3]=CubeDownTemp[7]
    CubeDown[4]=CubeDownTemp[4]
    CubeDown[5]=CubeDownTemp[1]
    CubeDown[6]=CubeDownTemp[8]
    CubeDown[7]=CubeDownTemp[5]
    CubeDown[8]=CubeDownTemp[2]

    CubeFront[6]=CubeLeftTemp[6]
    CubeFront[7]=CubeLeftTemp[7]
    CubeFront[8]=CubeLeftTemp[8]

    CubeLeft[6]=CubeBackTemp[6]
    CubeLeft[7]=CubeBackTemp[7]
    CubeLeft[8]=CubeBackTemp[8]

    CubeBack[6]=CubeRightTemp[6]
    CubeBack[7]=CubeRightTemp[7]
    CubeBack[8]=CubeRightTemp[8]

    CubeRight[6]=CubeFrontTemp[6]
    CubeRight[7]=CubeFrontTemp[7]
    CubeRight[8]=CubeFrontTemp[8]
    
    reFresh()
    
def moveDcounter():
    CubeFrontTemp  =  list(CubeFront)
    CubeBackTemp   =  list(CubeBack)
    CubeUpTemp     =  list(CubeUp)
    CubeDownTemp   =  list(CubeDown)
    CubeLeftTemp   =  list(CubeLeft)
    CubeRightTemp  =  list(CubeRight)
    
    CubeDown[0]=CubeDownTemp[2]
    CubeDown[1]=CubeDownTemp[5]
    CubeDown[2]=CubeDownTemp[8]
    CubeDown[3]=CubeDownTemp[1]
    CubeDown[4]=CubeDownTemp[4]
    CubeDown[5]=CubeDownTemp[7]
    CubeDown[6]=CubeDownTemp[0]
    CubeDown[7]=CubeDownTemp[3]
    CubeDown[8]=CubeDownTemp[6]

    CubeFront[6]=CubeRightTemp[6]
    CubeFront[7]=CubeRightTemp[7]
    CubeFront[8]=CubeRightTemp[8]

    CubeLeft[6]=CubeFrontTemp[6]
    CubeLeft[7]=CubeFrontTemp[7]
    CubeLeft[8]=CubeFrontTemp[8]

    CubeBack[6]=CubeLeftTemp[6]
    CubeBack[7]=CubeLeftTemp[7]
    CubeBack[8]=CubeLeftTemp[8]

    CubeRight[6]=CubeBackTemp[6]
    CubeRight[7]=CubeBackTemp[7]
    CubeRight[8]=CubeBackTemp[8]
    
    reFresh()
    
def moveL():
    CubeFrontTemp  =  list(CubeFront)
    CubeBackTemp   =  list(CubeBack)
    CubeUpTemp     =  list(CubeUp)
    CubeDownTemp   =  list(CubeDown)
    CubeLeftTemp   =  list(CubeLeft)
    CubeRightTemp  =  list(CubeRight)
    
    CubeLeft[0]=CubeLeftTemp[6]
    CubeLeft[1]=CubeLeftTemp[3]
    CubeLeft[2]=CubeLeftTemp[0]
    CubeLeft[3]=CubeLeftTemp[7]
    CubeLeft[4]=CubeLeftTemp[4]
    CubeLeft[5]=CubeLeftTemp[1]
    CubeLeft[6]=CubeLeftTemp[8]
    CubeLeft[7]=CubeLeftTemp[5]
    CubeLeft[8]=CubeLeftTemp[2]

    CubeFront[0]=CubeUpTemp[0]
    CubeFront[3]=CubeUpTemp[3]
    CubeFront[6]=CubeUpTemp[6]

    CubeUp[0]=CubeBackTemp[8]
    CubeUp[3]=CubeBackTemp[5]
    CubeUp[6]=CubeBackTemp[2]

    CubeBack[2]=CubeDownTemp[6]
    CubeBack[5]=CubeDownTemp[3]
    CubeBack[8]=CubeDownTemp[0]

    CubeDown[0]=CubeFrontTemp[0]
    CubeDown[3]=CubeFrontTemp[3]
    CubeDown[6]=CubeFrontTemp[6]
    
    reFresh()
    
def moveLcounter():
    CubeFrontTemp  =  list(CubeFront)
    CubeBackTemp   =  list(CubeBack)
    CubeUpTemp     =  list(CubeUp)
    CubeDownTemp   =  list(CubeDown)
    CubeLeftTemp   =  list(CubeLeft)
    CubeRightTemp  =  list(CubeRight)
    
    CubeLeft[0]=CubeLeftTemp[2]
    CubeLeft[1]=CubeLeftTemp[5]
    CubeLeft[2]=CubeLeftTemp[8]
    CubeLeft[3]=CubeLeftTemp[1]
    CubeLeft[4]=CubeLeftTemp[4]
    CubeLeft[5]=CubeLeftTemp[7]
    CubeLeft[6]=CubeLeftTemp[0]
    CubeLeft[7]=CubeLeftTemp[3]
    CubeLeft[8]=CubeLeftTemp[6]

    CubeUp[0]=CubeFrontTemp[0]
    CubeUp[3]=CubeFrontTemp[3]
    CubeUp[6]=CubeFrontTemp[6]

    CubeBack[2]=CubeUpTemp[6]
    CubeBack[5]=CubeUpTemp[3]
    CubeBack[8]=CubeUpTemp[0]

    CubeDown[0]=CubeBackTemp[8]
    CubeDown[3]=CubeBackTemp[5]
    CubeDown[6]=CubeBackTemp[2]

    CubeFront[0]=CubeDownTemp[0]
    CubeFront[3]=CubeDownTemp[3]
    CubeFront[6]=CubeDownTemp[6]
    
    reFresh()
    
def moveR():
    CubeFrontTemp  =  list(CubeFront)
    CubeBackTemp   =  list(CubeBack)
    CubeUpTemp     =  list(CubeUp)
    CubeDownTemp   =  list(CubeDown)
    CubeLeftTemp   =  list(CubeLeft)
    CubeRightTemp  =  list(CubeRight)
    
    CubeRight[0]=CubeRightTemp[6]
    CubeRight[1]=CubeRightTemp[3]
    CubeRight[2]=CubeRightTemp[0]
    CubeRight[3]=CubeRightTemp[7]
    CubeRight[4]=CubeRightTemp[4]
    CubeRight[5]=CubeRightTemp[1]
    CubeRight[6]=CubeRightTemp[8]
    CubeRight[7]=CubeRightTemp[5]
    CubeRight[8]=CubeRightTemp[2]

    CubeUp[2]=CubeFrontTemp[2]
    CubeUp[5]=CubeFrontTemp[5]
    CubeUp[8]=CubeFrontTemp[8]

    CubeBack[0]=CubeUpTemp[8]
    CubeBack[3]=CubeUpTemp[5]
    CubeBack[6]=CubeUpTemp[2]

    CubeDown[2]=CubeBackTemp[6]
    CubeDown[5]=CubeBackTemp[3]
    CubeDown[8]=CubeBackTemp[0]

    CubeFront[2]=CubeDownTemp[2]
    CubeFront[5]=CubeDownTemp[5]
    CubeFront[8]=CubeDownTemp[8]
    
    reFresh()
    
def moveRcounter():
    CubeFrontTemp  =  list(CubeFront)
    CubeBackTemp   =  list(CubeBack)
    CubeUpTemp     =  list(CubeUp)
    CubeDownTemp   =  list(CubeDown)
    CubeLeftTemp   =  list(CubeLeft)
    CubeRightTemp  =  list(CubeRight)
    
    CubeRight[0]=CubeRightTemp[2]
    CubeRight[1]=CubeRightTemp[5]
    CubeRight[2]=CubeRightTemp[8]
    CubeRight[3]=CubeRightTemp[1]
    CubeRight[4]=CubeRightTemp[4]
    CubeRight[5]=CubeRightTemp[7]
    CubeRight[6]=CubeRightTemp[0]
    CubeRight[7]=CubeRightTemp[3]
    CubeRight[8]=CubeRightTemp[6]

    CubeFront[2]=CubeUpTemp[2]
    CubeFront[5]=CubeUpTemp[5]
    CubeFront[8]=CubeUpTemp[8]

    CubeUp[2]=CubeBackTemp[6]
    CubeUp[5]=CubeBackTemp[3]
    CubeUp[8]=CubeBackTemp[0]

    CubeBack[0]=CubeDownTemp[8]
    CubeBack[3]=CubeDownTemp[5]
    CubeBack[6]=CubeDownTemp[2]

    CubeDown[2]=CubeFrontTemp[2]
    CubeDown[5]=CubeFrontTemp[5]
    CubeDown[8]=CubeFrontTemp[8]
    
    reFresh()
    
    
def moveShuffle():
    ShuffleList=[]
    for ShuffleAdder in range(30):
            ShuffleList.append(MovesList[randint(0,11)])
            
    for ShuffleChecker in range (29):
        if ShuffleList[ShuffleChecker]==ShuffleList[ShuffleChecker+1]+"'" or ShuffleList[ShuffleChecker]+"'"==ShuffleList[ShuffleChecker+1]:
            ShuffleList[ShuffleChecker]=MovesList[randint(0,11)]
            
    if len(ShuffleList)>30:
        ShuffleList.remove(ShuffleList[30])
        
    elif len(ShuffleList)<30:
        ShuffleList.append(MovesList[randint(0,11)])
        
    for ShuffleChecker in range (28):
        if ShuffleList[ShuffleChecker]==ShuffleList[ShuffleChecker+1]==ShuffleList[ShuffleChecker+2]:
            
            if "'" in ShuffleList[ShuffleChecker]:
                ShuffleList[ShuffleChecker:ShuffleChecker+3]=ShuffleList[ShuffleChecker].strip("'")
                
            elif "'" not in ShuffleList[ShuffleChecker]:
                ShuffleList[ShuffleChecker:ShuffleChecker+3]=ShuffleList[ShuffleChecker]+"'"
                
            ShuffleList.append(MovesList[randint(0,11)])
            
    if len(ShuffleList)>30:
        ShuffleList.remove(ShuffleList[30])
        
    elif len(ShuffleList)<30:
        ShuffleList.append(MovesList[randint(0,11)])
    
    
    #checken nog niet optimaal...
        
    for ShuffleExe in range(len(ShuffleList)):

        CubeFrontTemp  =  list(CubeFront)
        CubeBackTemp   =  list(CubeBack)
        CubeUpTemp     =  list(CubeUp)
        CubeDownTemp   =  list(CubeDown)
        CubeLeftTemp   =  list(CubeLeft)
        CubeRightTemp  =  list(CubeRight)

        if ShuffleList[ShuffleExe]=="F":
            moveF()

        elif ShuffleList[ShuffleExe]=="F'":
            moveFcounter()
            
        elif ShuffleList[ShuffleExe]=="B":
            moveB()

        elif ShuffleList[ShuffleExe]=="B'":
            moveBcounter()

        elif ShuffleList[ShuffleExe]=="U":
            moveU()

        elif ShuffleList[ShuffleExe]=="U'":
            moveUcounter()

        elif ShuffleList[ShuffleExe]=="D":
            moveD()

        elif ShuffleList[ShuffleExe]=="D'":
            moveDcounter()

        elif ShuffleList[ShuffleExe]=="L":
            moveL()

        elif ShuffleList[ShuffleExe]=="L'":
            moveLcounter()
            
        elif ShuffleList[ShuffleExe]=="R":
            moveR()
            
        elif ShuffleList[ShuffleExe]=="R'":
            moveRcounter()
        
            
            
    reFresh()
        
    tkMessageBox.showinfo("Shuffle", ShuffleList )  
    
    """print len(ShuffleList)""" #als je checkt voor aantal elementen

    

def Clear():
    CubeFront[0]="blue"
    CubeFront[1]="blue"
    CubeFront[2]="blue"
    CubeFront[3]="blue"
    CubeFront[4]="blue"
    CubeFront[5]="blue"
    CubeFront[6]="blue"
    CubeFront[7]="blue"
    CubeFront[8]="blue"
    
    CubeLeft[0]="red"
    CubeLeft[1]="red"
    CubeLeft[2]="red"
    CubeLeft[3]="red"
    CubeLeft[4]="red"
    CubeLeft[5]="red"
    CubeLeft[6]="red"
    CubeLeft[7]="red"
    CubeLeft[8]="red"
    
    CubeRight[0]="orange"
    CubeRight[1]="orange"
    CubeRight[2]="orange"
    CubeRight[3]="orange"
    CubeRight[4]="orange"
    CubeRight[5]="orange"
    CubeRight[6]="orange"
    CubeRight[7]="orange"
    CubeRight[8]="orange"
    
    CubeBack[0]="green"
    CubeBack[1]="green"
    CubeBack[2]="green"
    CubeBack[3]="green"
    CubeBack[4]="green"
    CubeBack[5]="green"
    CubeBack[6]="green"
    CubeBack[7]="green"
    CubeBack[8]="green"
    
    CubeUp[0]="white"
    CubeUp[1]="white"
    CubeUp[2]="white"
    CubeUp[3]="white"
    CubeUp[4]="white"
    CubeUp[5]="white"
    CubeUp[6]="white"
    CubeUp[7]="white"
    CubeUp[8]="white"
    
    CubeDown[0]="yellow"
    CubeDown[1]="yellow"
    CubeDown[2]="yellow"
    CubeDown[3]="yellow"
    CubeDown[4]="yellow"
    CubeDown[5]="yellow"
    CubeDown[6]="yellow"
    CubeDown[7]="yellow"
    CubeDown[8]="yellow"    

    reFresh()


def Solve():
    tkMessageBox.showinfo("Solve", "You wish, don't you?" )
    
    
    


CubeWindow=Tk()
CubeWindow.title("Virtual Cube")
CubeWindow.geometry("650x600")
CubeWindow.resizable(0,0)
#hierdoor kan je hem niet veranderen van grootte

topFrame=Frame(CubeWindow)
topFrame.pack()

bottomFrame=Frame(CubeWindow)
bottomFrame.pack(side=BOTTOM)


ButtonF=Button(bottomFrame, text="F", width=10, command=moveF)
ButtonF.pack()
ButtonF.grid(row=0, column=0)

ButtonFcounter=Button(bottomFrame, text="F'", width=10, command=moveFcounter)
ButtonFcounter.pack()
ButtonFcounter.grid(row=1, column=0)

ButtonB=Button(bottomFrame, text="B", width=10, command=moveB)
ButtonB.pack()
ButtonB.grid(row=0, column=1)

ButtonBcounter=Button(bottomFrame, text="B'", width=10, command=moveBcounter)
ButtonBcounter.pack()
ButtonBcounter.grid(row=1, column=1)

ButtonU=Button(bottomFrame, text="U", width=10, command=moveU)
ButtonU.pack()
ButtonU.grid(row=0, column=2)

ButtonUcounter=Button(bottomFrame, text="U'", width=10, command=moveUcounter)
ButtonUcounter.pack()
ButtonUcounter.grid(row=1, column=2)

ButtonD=Button(bottomFrame, text="D", width=10, command=moveD)
ButtonD.pack()
ButtonD.grid(row=0, column=3)

ButtonDcounter=Button(bottomFrame, text="D'", width=10, command=moveDcounter)
ButtonDcounter.pack()
ButtonDcounter.grid(row=1, column=3)

ButtonL=Button(bottomFrame, text="L", width=10, command=moveL)
ButtonL.pack()
ButtonL.grid(row=0, column=4)

ButtonLcounter=Button(bottomFrame, text="L'", width=10, command=moveLcounter)
ButtonLcounter.pack()
ButtonLcounter.grid(row=1, column=4)

ButtonR=Button(bottomFrame, text="R", width=10, command=moveR)
ButtonR.pack()
ButtonR.grid(row=0, column=5)

ButtonRcounter=Button(bottomFrame, text="R'", width=10, command=moveRcounter)
ButtonRcounter.pack()
ButtonRcounter.grid(row=1, column=5)

ButtonShuffle=Button(bottomFrame, text="Shuffle", width=10, height=3, command=moveShuffle)
ButtonShuffle.pack()
ButtonShuffle.grid(row=0, column=6, rowspan=2)

ButtonReset=Button(bottomFrame, text="Reset", width=10, height=3, command=Clear)
ButtonReset.pack()
ButtonReset.grid(row=0, column=7, rowspan=2)

ButtonSolve=Button(bottomFrame, text="Solve", width=90, command=Solve)
ButtonSolve.pack()
ButtonSolve.grid(row=3, column=0, columnspan=8)


CubeVisual= Canvas(topFrame, width=600, height=450)
CubeVisual.configure(background="gray")
CubeVisual.pack()

U0=CubeVisual.create_rectangle(301, 1, 349, 49, fill=CubeUp[0], outline="black")
U1=CubeVisual.create_rectangle(351, 1, 399, 49, fill=CubeUp[1], outline="black")
U2=CubeVisual.create_rectangle(401, 1, 449, 49, fill=CubeUp[2], outline="black")
U3=CubeVisual.create_rectangle(301, 51, 349, 99, fill=CubeUp[3], outline="black")
U4=CubeVisual.create_rectangle(351, 51, 399, 99, fill=CubeUp[4], outline="black")
U5=CubeVisual.create_rectangle(401, 51, 449, 99, fill=CubeUp[5], outline="black")
U6=CubeVisual.create_rectangle(301, 101, 349, 149, fill=CubeUp[6], outline="black")
U7=CubeVisual.create_rectangle(351, 101, 399, 149, fill=CubeUp[7], outline="black") 
U8=CubeVisual.create_rectangle(401, 101, 449, 149, fill=CubeUp[8], outline="black")

B0=CubeVisual.create_rectangle(1, 151, 49, 199, fill=CubeBack[0], outline="black")
B1=CubeVisual.create_rectangle(51, 151, 99, 199, fill=CubeBack[1], outline="black")
B2=CubeVisual.create_rectangle(101, 151, 149, 199, fill=CubeBack[2], outline="black")
B3=CubeVisual.create_rectangle(1, 201, 49, 249, fill=CubeBack[3], outline="black")
B4=CubeVisual.create_rectangle(51, 201, 99, 249, fill=CubeBack[4], outline="black")
B5=CubeVisual.create_rectangle(101, 201, 149, 249, fill=CubeBack[5], outline="black")
B6=CubeVisual.create_rectangle(1, 251, 49, 299, fill=CubeBack[6], outline="black")
B7=CubeVisual.create_rectangle(51, 251, 99, 299, fill=CubeBack[7], outline="black")
B8=CubeVisual.create_rectangle(101, 251, 149, 299, fill=CubeBack[8], outline="black")

L0=CubeVisual.create_rectangle(151, 151, 199, 199, fill=CubeLeft[0], outline="black")
L1=CubeVisual.create_rectangle(201, 151, 249, 199, fill=CubeLeft[1], outline="black")
L2=CubeVisual.create_rectangle(251, 151, 299, 199, fill=CubeLeft[2], outline="black")
L3=CubeVisual.create_rectangle(151, 201, 199, 249, fill=CubeLeft[3], outline="black")
L4=CubeVisual.create_rectangle(201, 201, 249, 249, fill=CubeLeft[4], outline="black")
L5=CubeVisual.create_rectangle(251, 201, 299, 249, fill=CubeLeft[5], outline="black")
L6=CubeVisual.create_rectangle(151, 251, 199, 299, fill=CubeLeft[6], outline="black")
L7=CubeVisual.create_rectangle(201, 251, 249, 299, fill=CubeLeft[7], outline="black")
L8=CubeVisual.create_rectangle(251, 251, 299, 299, fill=CubeLeft[8], outline="black")

F0=CubeVisual.create_rectangle(301, 151, 349, 199, fill=CubeFront[0], outline="black")
F1=CubeVisual.create_rectangle(351, 151, 399, 199, fill=CubeFront[1], outline="black")
F2=CubeVisual.create_rectangle(401, 151, 449, 199, fill=CubeFront[2], outline="black")
F3=CubeVisual.create_rectangle(301, 201, 349, 249, fill=CubeFront[3], outline="black")
F4=CubeVisual.create_rectangle(351, 201, 399, 249, fill=CubeFront[4], outline="black")
F5=CubeVisual.create_rectangle(401, 201, 449, 249, fill=CubeFront[5], outline="black")
F6=CubeVisual.create_rectangle(301, 251, 349, 299, fill=CubeFront[6], outline="black")
F7=CubeVisual.create_rectangle(351, 251, 399, 299, fill=CubeFront[7], outline="black")
F8=CubeVisual.create_rectangle(401, 251, 449, 299, fill=CubeFront[8], outline="black")

R0=CubeVisual.create_rectangle(451, 151, 499, 199, fill=CubeRight[0], outline="black")
R1=CubeVisual.create_rectangle(501, 151, 549, 199, fill=CubeRight[1], outline="black")
R2=CubeVisual.create_rectangle(551, 151, 599, 199, fill=CubeRight[2], outline="black")
R3=CubeVisual.create_rectangle(451, 201, 499, 249, fill=CubeRight[3], outline="black")
R4=CubeVisual.create_rectangle(501, 201, 549, 249, fill=CubeRight[4], outline="black")
R5=CubeVisual.create_rectangle(551, 201, 599, 249, fill=CubeRight[5], outline="black")
R6=CubeVisual.create_rectangle(451, 251, 499, 299, fill=CubeRight[6], outline="black")
R7=CubeVisual.create_rectangle(501, 251, 549, 299, fill=CubeRight[7], outline="black")
R8=CubeVisual.create_rectangle(551, 251, 599, 299, fill=CubeRight[8], outline="black")

D0=CubeVisual.create_rectangle(301, 301, 349, 349, fill=CubeDown[0], outline="black")
D1=CubeVisual.create_rectangle(351, 301, 399, 349, fill=CubeDown[1], outline="black")
D2=CubeVisual.create_rectangle(401, 301, 449, 349, fill=CubeDown[2], outline="black")
D3=CubeVisual.create_rectangle(301, 351, 349, 399, fill=CubeDown[3], outline="black")
D4=CubeVisual.create_rectangle(351, 351, 399, 399, fill=CubeDown[4], outline="black")
D5=CubeVisual.create_rectangle(401, 351, 449, 399, fill=CubeDown[5], outline="black")
D6=CubeVisual.create_rectangle(301, 401, 349, 449, fill=CubeDown[6], outline="black")
D7=CubeVisual.create_rectangle(351, 401, 399, 449, fill=CubeDown[7], outline="black")
D8=CubeVisual.create_rectangle(401, 401, 449, 449, fill=CubeDown[8], outline="black")



CubeWindow.mainloop()
