# %%
from random import randint
from copy import deepcopy

# %%
def initcube():
    cube = [["b" for i in range(4)], ["g" for i in range(4)], ["w" for i in range(4)], \
            ["y" for i in range(4)], ["r" for i in range(4)], \
            ["o" for i in range(4)], ["ufl", "ufr", "ubr", "ubl", "dfl", "dfr", "dbr", "dbl"]]
    return cube
def printc2(cube):
    for i in range(6):
        print cube[i][0], cube[i][1]
        print cube[i][2], cube[i][3]
def turnface(face):
    face[0], face[1], face[3], face[2] = face[2], face[0], face[1], face[3]
def F(cube):
    f, b, u, d, l, r, c = cube
    turnface(f)
    u[2], u[3], r[0], r[2], d[1], d[0], l[3], l[1] = l[3], l[1], u[2], u[3], r[0], r[2], d[1], d[0]
    c[0], c[1], c[5], c[4] = c[4], c[0], c[1], c[5]
    return cube
def F2(cube):
    for i in range(2):
        F(cube)
    return cube
def Fc(cube):
    for i in range(3):
        F(cube)
    return cube
def B(cube):
    f, b, u, d, l, r, c = cube
    turnface(b)
    u[1], u[0], l[0], l[2], d[3], d[2], r[3], r[1] = r[3], r[1], u[1], u[0], l[0], l[2], d[3], d[2]
    c[2], c[3], c[7], c[6] = c[6], c[2], c[3], c[7]
    return cube
def B2(cube):
    for i in range(2):
        B(cube)
    return cube
def Bc(cube):
    for i in range(3):
        B(cube)
    return cube
def U(cube):
    f, b, u, d, l, r, c = cube
    turnface(u)
    b[1], b[0], r[1], r[0], f[1], f[0], l[1], l[0] = l[1], l[0], b[1], b[0], r[1], r[0], f[1], f[0]
    c[3], c[2], c[1], c[0] = c[0], c[3], c[2], c[1]
    return cube
def U2(cube):
    for i in range(2):
        U(cube)
    return cube
def Uc(cube):
    for i in range(3):
        U(cube)
    return cube
def D(cube):
    f, b, u, d, l, r, c = cube
    turnface(d)
    f[2], f[3], r[2], r[3], b[2], b[3], l[2], l[3] = l[2], l[3], f[2], f[3], r[2], r[3], b[2], b[3]
    c[4], c[5], c[6], c[7] = c[7], c[4], c[5], c[6]
    return cube
def D2(cube):
    for i in range(2):
        D(cube)
    return cube
def Dc(cube):
    for i in range(3):
        D(cube)
    return cube
def L(cube):
    f, b, u, d, l, r, c = cube
    turnface(l)
    u[0], u[2], f[0], f[2], d[0], d[2], b[3], b[1] = b[3], b[1], u[0], u[2], f[0], f[2], d[0], d[2]
    c[3], c[0], c[4], c[7] = c[7], c[3], c[0], c[4]
    return cube
def L2(cube):
    for i in range(2):
        L(cube)
    return cube
def Lc(cube):
    for i in range(3):
        L(cube)
    return cube
def R(cube):
    f, b, u, d, l, r, c = cube
    turnface(r)
    u[3], u[1], b[0], b[2], d[3], d[1], f[3], f[1] = f[3], f[1], u[3], u[1], b[0], b[2], d[3], d[1]
    c[1], c[2], c[6], c[5] = c[5], c[1], c[2], c[6]
    return cube
def R2(cube):
    for i in range(2):
        R(cube)
    return cube
def Rc(cube):
    for i in range(3):
        R(cube)
    return cube
